# %% [markdown]
# # This is my coding exercise

# %%
print("Hello World 2!")
# Out:
# Hello World 2!

# %%
lst = [1, 2, 3]

print(lst)
# Out:
# [1, 2, 3]

# %%
import matplotlib.pyplot as plt


plt.plot([1, 2], [1, 2])
plt.show()
